# %% [markdown]
# # Jonathan Bradley - CS4319 - Homework 4

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Jonathan\Desktop\School\CS 4319\Glioblastoma_5Class\Data_Glioblastoma5Patients_SC.csv")
data
# Out:
#           A2M      AAAS      AAK1      AAMP      AARS    AARSD1     AASDH  \
# 0   -3.801470 -3.889900 -3.985616  2.651558  2.170748 -2.550822  4.807330
# 1   -3.801470 -3.889900 -3.158708  2.358992 -6.041792 -0.056092  3.606735
# 2   -3.801470 -3.889900  1.733125 -5.820241 -6.041792 -0.576957 -2.473517
# 3   -3.801470 -3.889900 -1.665669  3.514271 -6.041792 -3.699171  4.509461
# 4   -3.801470  3.742495 -2.166992 -5.820241  2.094729  4.021873  5.535007
# ..        ...       ...       ...       ...       ...       ...       ...
# 425  0.049047  3.802559  0.569558  2.277677 -3.588918  3.061068  4.605986
# 426 -3.801470 -3.889900  3.696882  2.838116 -0.613635 -3.699171 -2.473517
# 427 -0.264648 -3.889900 -1.092769 -1.215363 -6.041792 -3.699171 -2.473517
# 428 -3.801470  3.616363  2.991430  1.747092  3.499675  3.630346 -2.473517
# 429 -3.801470 -1.258929  2.012230  1.652332  3.667814  3.149795  3.828736
#
#      AASDHPPT      AASS      AATF  ...    ZSWIM6    ZSWIM7     ZUFSP  \
# ...

# %%
data["Classes"].value_counts()
# Out:
# Class1    118
# Class2     94
# Class3     75
# Class4     73
# Class5     70
# Name: Classes, dtype: int64

# %%
feature_vectors = data.drop(['Classes'], axis = 1)
feature_vectors
# Out:
#           A2M      AAAS      AAK1      AAMP      AARS    AARSD1     AASDH  \
# 0   -3.801470 -3.889900 -3.985616  2.651558  2.170748 -2.550822  4.807330
# 1   -3.801470 -3.889900 -3.158708  2.358992 -6.041792 -0.056092  3.606735
# 2   -3.801470 -3.889900  1.733125 -5.820241 -6.041792 -0.576957 -2.473517
# 3   -3.801470 -3.889900 -1.665669  3.514271 -6.041792 -3.699171  4.509461
# 4   -3.801470  3.742495 -2.166992 -5.820241  2.094729  4.021873  5.535007
# ..        ...       ...       ...       ...       ...       ...       ...
# 425  0.049047  3.802559  0.569558  2.277677 -3.588918  3.061068  4.605986
# 426 -3.801470 -3.889900  3.696882  2.838116 -0.613635 -3.699171 -2.473517
# 427 -0.264648 -3.889900 -1.092769 -1.215363 -6.041792 -3.699171 -2.473517
# 428 -3.801470  3.616363  2.991430  1.747092  3.499675  3.630346 -2.473517
# 429 -3.801470 -1.258929  2.012230  1.652332  3.667814  3.149795  3.828736
#
#      AASDHPPT      AASS      AATF  ...   ZSCAN30    ZSWIM6    ZSWIM7  \
# ...

# %%
classes = data['Classes'].values
classes
# Out:
# array(['Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
#        'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature_vectors, classes, test_size = 0.2, random_state = 42, stratify=classes)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
LR = LogisticRegression(multi_class = 'multinomial')
LRT = LR.fit(X_train, y_train)
y_predict_LR = LRT.predict(X_test)
print(classification_report(y_test, y_predict_LR))
# Out:
#               precision    recall  f1-score   support
#
#       Class1       1.00      1.00      1.00        23
#       Class2       0.95      1.00      0.97        19
#       Class3       1.00      1.00      1.00        15
#       Class4       1.00      0.87      0.93        15
#       Class5       0.93      1.00      0.97        14
#
#     accuracy                           0.98        86
#    macro avg       0.98      0.97      0.97        86
# weighted avg       0.98      0.98      0.98        86

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(f'Decision tree has {tree.tree_.node_count} nodes with maximum depth {tree.tree_.max_depth}.')
print(f'Accuracy: {tree.score(X_train, y_train)}')
# Out:
# Decision tree has 33 nodes with maximum depth 8.
# Accuracy: 1.0

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier()

RFC.fit(X_train, y_train)
print(classification_report(y_test, RFC.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#       Class1       1.00      1.00      1.00        23
#       Class2       0.95      1.00      0.97        19
#       Class3       1.00      1.00      1.00        15
#       Class4       1.00      0.87      0.93        15
#       Class5       0.93      1.00      0.97        14
#
#     accuracy                           0.98        86
#    macro avg       0.98      0.97      0.97        86
# weighted avg       0.98      0.98      0.98        86

# %% [markdown]
# ### SVM

# %% [markdown]
# ### MLP
